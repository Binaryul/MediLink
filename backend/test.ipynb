# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("../database/MediLink.db")
c = conn.cursor()

# %%
df = pd.read_sql_query("""
        SELECT * 
        FROM Notices
        INNER JOIN NoticeContent ON Notices.noticeID = NoticeContent.noticeID
    """, conn)

# %%
df
# Out:
#   patientID noticeID doctorID noticeID        Date  \
# 0   BM00001  NT00001  TC00001  NT00001  2025-12-11
#
#                                              Message
# 0  Your appointment is scheduled for 2024-11-20 a...
